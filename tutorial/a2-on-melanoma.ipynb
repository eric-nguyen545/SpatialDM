# %% [markdown]
# # SpatialDM tutorial with melanoma data

# %% [markdown]
# You may also run it on Google Colab with this link: [melanoma.ipynb](https://colab.research.google.com/github/StatBiomed/SpatialDM/blob/main/tutorial/melanoma.ipynb)
#
# For the scripts below, please only install the package if you need (required on colab) but on your local environment, you only need to install for the first time.

# %%
# install scipy<=1.11.4 for use SpatialDE
# !pip install scipy==1.11.4

# install anndata <= 0.10.8 to avoid complicated cupy package
# !pip install anndata==0.10.8

# install latest SpatialDM from github directly
# !pip install -U git+https://github.com/StatBiomed/SpatialDM

# !pip install SparseAEH
# Out:
# Requirement already satisfied: scipy==1.11.4 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scipy==1.11.4) (1.26.4)
# Requirement already satisfied: anndata==0.10.8 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (0.10.8)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata==0.10.8) (1.9.1)
# Requirement already satisfied: exceptiongroup in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata==0.10.8) (1.2.2)
# Requirement already satisfied: h5py>=3.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata==0.10.8) (3.12.1)
# Requirement already satisfied: natsort in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata==0.10.8) (8.4.0)
# Requirement already satisfied: numpy>=1.23 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata==0.10.8) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata==0.10.8) (24.1)
# Requirement already satisfied: pandas!=2.1.0rc0,!=2.1.2,>=1.4 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata==0.10.8) (2.2.3)
# Requirement already satisfied: scipy>1.8 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata==0.10.8) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.8) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.8) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.8) (2024.2)
# Requirement already satisfied: six>=1.5 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.8) (1.16.0)
# Collecting git+https://github.com/StatBiomed/SpatialDM
#   Cloning https://github.com/StatBiomed/SpatialDM to /tmp/pip-req-build-yxfjb9k1
#   Running command git clone --filter=blob:none --quiet https://github.com/StatBiomed/SpatialDM /tmp/pip-req-build-yxfjb9k1
#   Resolved https://github.com/StatBiomed/SpatialDM to commit a4b42a38c136eea5c01520792810b861b9600e68
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: anndata>=0.6 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (0.10.8)
# Requirement already satisfied: scanpy>=1.5 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (1.10.3)
# Requirement already satisfied: SpatialDE in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (1.1.3)
# Requirement already satisfied: numpy>=1.9.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (1.26.4)
# Requirement already satisfied: scipy>=1.4.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (1.11.4)
# Requirement already satisfied: statsmodels>=0.11 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (0.14.4)
# Requirement already satisfied: pandas>=0.23.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (2.2.3)
# Requirement already satisfied: h5py>=2.9.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (3.12.1)
# Requirement already satisfied: matplotlib>=3.1.2 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (3.9.2)
# Requirement already satisfied: holoviews in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (1.20.0)
# Requirement already satisfied: seaborn in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (0.13.2)
# Requirement already satisfied: selenium in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (4.26.1)
# Requirement already satisfied: scikit-learn>=0.23 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (1.5.2)
# Requirement already satisfied: hilearn in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (0.2.2)
# Requirement already satisfied: threadpoolctl in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDM==0.2.0) (3.5.0)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata>=0.6->SpatialDM==0.2.0) (1.9.1)
# Requirement already satisfied: exceptiongroup in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata>=0.6->SpatialDM==0.2.0) (1.2.2)
# Requirement already satisfied: natsort in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata>=0.6->SpatialDM==0.2.0) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from anndata>=0.6->SpatialDM==0.2.0) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from matplotlib>=3.1.2->SpatialDM==0.2.0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from matplotlib>=3.1.2->SpatialDM==0.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from matplotlib>=3.1.2->SpatialDM==0.2.0) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from matplotlib>=3.1.2->SpatialDM==0.2.0) (1.4.7)
# Requirement already satisfied: pillow>=8 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from matplotlib>=3.1.2->SpatialDM==0.2.0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from matplotlib>=3.1.2->SpatialDM==0.2.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from matplotlib>=3.1.2->SpatialDM==0.2.0) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from matplotlib>=3.1.2->SpatialDM==0.2.0) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from pandas>=0.23.0->SpatialDM==0.2.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from pandas>=0.23.0->SpatialDM==0.2.0) (2024.2)
# Requirement already satisfied: get-annotations in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (0.1.2)
# Requirement already satisfied: joblib in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (1.4.2)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (1.4)
# Requirement already satisfied: networkx>=2.7 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (3.2.1)
# Requirement already satisfied: numba>=0.56 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (0.60.0)
# Requirement already satisfied: patsy in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (0.5.6)
# Requirement already satisfied: pynndescent>=0.5 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (0.5.13)
# Requirement already satisfied: session-info in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (1.0.0)
# Requirement already satisfied: tqdm in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (4.66.6)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scanpy>=1.5->SpatialDM==0.2.0) (0.5.7)
# Requirement already satisfied: bokeh>=3.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from holoviews->SpatialDM==0.2.0) (3.4.3)
# Requirement already satisfied: colorcet in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from holoviews->SpatialDM==0.2.0) (3.1.0)
# Requirement already satisfied: panel>=1.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from holoviews->SpatialDM==0.2.0) (1.4.5)
# Requirement already satisfied: param<3.0,>=2.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from holoviews->SpatialDM==0.2.0) (2.1.1)
# Requirement already satisfied: pyviz-comms>=2.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from holoviews->SpatialDM==0.2.0) (3.0.3)
# Requirement already satisfied: urllib3<3,>=1.26 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from urllib3[socks]<3,>=1.26->selenium->SpatialDM==0.2.0) (2.2.3)
# Requirement already satisfied: trio~=0.17 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from selenium->SpatialDM==0.2.0) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from selenium->SpatialDM==0.2.0) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from selenium->SpatialDM==0.2.0) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from selenium->SpatialDM==0.2.0) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from selenium->SpatialDM==0.2.0) (1.8.0)
# Requirement already satisfied: NaiveDE in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDE->SpatialDM==0.2.0) (1.2.0)
# Requirement already satisfied: Click in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SpatialDE->SpatialDM==0.2.0) (8.1.7)
# Requirement already satisfied: Jinja2>=2.9 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from bokeh>=3.1->holoviews->SpatialDM==0.2.0) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from bokeh>=3.1->holoviews->SpatialDM==0.2.0) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from bokeh>=3.1->holoviews->SpatialDM==0.2.0) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from bokeh>=3.1->holoviews->SpatialDM==0.2.0) (2024.9.0)
# Requirement already satisfied: zipp>=3.1.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.1.2->SpatialDM==0.2.0) (3.20.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from numba>=0.56->scanpy>=1.5->SpatialDM==0.2.0) (0.43.0)
# Requirement already satisfied: markdown in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from panel>=1.0->holoviews->SpatialDM==0.2.0) (3.7)
# Requirement already satisfied: markdown-it-py in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from panel>=1.0->holoviews->SpatialDM==0.2.0) (3.0.0)
# Requirement already satisfied: linkify-it-py in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from panel>=1.0->holoviews->SpatialDM==0.2.0) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from panel>=1.0->holoviews->SpatialDM==0.2.0) (0.4.2)
# Requirement already satisfied: requests in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from panel>=1.0->holoviews->SpatialDM==0.2.0) (2.32.3)
# Requirement already satisfied: bleach in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from panel>=1.0->holoviews->SpatialDM==0.2.0) (6.2.0)
# Requirement already satisfied: six in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from patsy->scanpy>=1.5->SpatialDM==0.2.0) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from trio~=0.17->selenium->SpatialDM==0.2.0) (24.2.0)
# Requirement already satisfied: sortedcontainers in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from trio~=0.17->selenium->SpatialDM==0.2.0) (2.4.0)
# Requirement already satisfied: idna in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from trio~=0.17->selenium->SpatialDM==0.2.0) (3.10)
# Requirement already satisfied: outcome in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from trio~=0.17->selenium->SpatialDM==0.2.0) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from trio~=0.17->selenium->SpatialDM==0.2.0) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium->SpatialDM==0.2.0) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from urllib3[socks]<3,>=1.26->selenium->SpatialDM==0.2.0) (1.7.1)
# Requirement already satisfied: stdlib-list in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from session-info->scanpy>=1.5->SpatialDM==0.2.0) (0.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews->SpatialDM==0.2.0) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->SpatialDM==0.2.0) (0.14.0)
# Requirement already satisfied: webencodings in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from bleach->panel>=1.0->holoviews->SpatialDM==0.2.0) (0.5.1)
# Requirement already satisfied: uc-micro-py in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from linkify-it-py->panel>=1.0->holoviews->SpatialDM==0.2.0) (1.0.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from markdown->panel>=1.0->holoviews->SpatialDM==0.2.0) (8.5.0)
# Requirement already satisfied: mdurl~=0.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from markdown-it-py->panel>=1.0->holoviews->SpatialDM==0.2.0) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from requests->panel>=1.0->holoviews->SpatialDM==0.2.0) (3.4.0)
# Requirement already satisfied: SparseAEH in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (0.1.0)
# Requirement already satisfied: numpy in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SparseAEH) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SparseAEH) (1.11.4)
# Requirement already satisfied: pandas>=0.23 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SparseAEH) (2.2.3)
# Requirement already satisfied: scikit-learn in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from SparseAEH) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from pandas>=0.23->SparseAEH) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from pandas>=0.23->SparseAEH) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from pandas>=0.23->SparseAEH) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scikit-learn->SparseAEH) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from scikit-learn->SparseAEH) (3.5.0)
# Requirement already satisfied: six>=1.5 in /mnt/jackywang/nfs_share/anaconda3/envs/sdm2/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->SparseAEH) (1.16.0)

# %%
import os
import pandas as pd
import numpy as np
import anndata as ann

import spatialdm as sdm
from spatialdm.datasets import dataset
import spatialdm.plottings as pl

import matplotlib.pyplot as plt
print("SpatailDM version: %s" %sdm.__version__)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# SpatailDM version: 0.2.0

# %% [markdown]
# The melanoma dataset from [Thrane, et al. 2018 Caner Cell](https://aacrjournals.org/cancerres/article/78/20/5970/631815) was publicly available.
# We obtained raw counts, pre-processed log counts, and spatial coordinates from Matt Stone ([Git repository](https://github.com/msto/spatial-datasets)). For easier reuse, we included them in an anndata object which can be loaded directly in SpatialDM Python package.
#
# We can see the histology image below from the orignal supplementary figure (the first sample):
#
# <img src="https://aacr.silverchair-cdn.com/aacr/content_public/journal/cancerres/78/20/10.1158_0008-5472.can-18-0747/3/00085472can180747-sup-198251_2_supp_4942305_pd1ntm.png" width="500" />
#
# For the cell type annotation, we can visualize it from SpatialDM's paper [Figure 2b](https://www.nature.com/articles/s41467-023-39608-w/figures/2).

# %%
adata = dataset.A2()

# %% [markdown]
# The anndata object contains the following:\
#     log-transformed expression in `adata.X`, \
#     raw expression in `adata.raw`,\
#     cell types computed by RCTD in `adata.obs`,\
#     and spatial coordinates in `adata.obsm['spatial']`

# %% [markdown]
# ## SpatialDM object and preprocessing

# %% [markdown]
# We generate a suitable weight matrix for the SpatialDM object at first. Here considering the scale of the spatial coordinates and spot-spot distance (200 micrometers here), we set radial basis kernel parameter l = 1.2, and trimmed all weights < 0.2 (cutoff) to match the normal range of CCC (200 micrometers, 1 spot away from the sender cell here)

# %% [markdown]
# <div class="alert alert-info">
#
# **Note**
# Alternative to the cutoff parameter, we can set n_neighbors to around 8 to restrain the range of CCC.
#
# </div>

# %%
import os
import pandas as pd
import numpy as np
import anndata as ann

import spatialdm as sdm
from spatialdm.datasets import dataset
import spatialdm.plottings as pl

import matplotlib.pyplot as plt

adata = dataset.A3()

adata.obsm['spatial'] = adata.obsm['spatial'].values
sdm.weight_matrix(adata, l=75, cutoff= 0.2, single_cell=True) # weight_matrix by rbf kernel

# visualize range of interaction
import matplotlib.pyplot as plt
plt.figure(figsize=(3,3))

# plt.scatter(adata.obsm['spatial'][:,0], adata.obsm['spatial'][:,1], 
#             c=adata.obsp['weight'][50])

plt.scatter(adata.obsm['spatial'][:,0], adata.obsm['spatial'][:,1], 
            c=adata.obsp['weight'].A[50])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 15
#      12 adata = dataset.A3()
#      14 adata.obsm['spatial'] = adata.obsm['spatial'].values
# ---> 15 sdm.weight_matrix(adata, l=75, cutoff= 0.2, single_cell=True) # weight_matrix by rbf kernel
#      17 # visualize range of interaction
#      18 import matplotlib.pyplot as plt
#
# File ~\anaconda3\envs\bio\lib\site-packages\spatialdm\main.py:68, in weight_matrix(adata, l, cutoff, n_neighbors, n_nearest_neighbors, single_cell, eff_dist)
#      62 nnbrs = NearestNeighbors(
#      63     n_neighbors=n_neighbors,
#      64     algorithm='ball_tree',
#      65     metric='euclidean'
#      66 ).fit(X_loc)
#      67 nbr_d = nnbrs.kneighbors_graph(X_loc, mode='distance')
# ---> 68 rbf_d = _Euclidean_to_RBF(nbr_d, l, single_cell)
#      70 ## small neighborhood for RBF
#      71 nnbrs0 = NearestNeighbors(
#      72     n_neighbors=n_nearest_neighbors,
#      73     algorithm='ball_tree',
#      74     metric='euclidean'
#      75 ).fit(X_loc)
#
# File ~\anaconda3\envs\bio\lib\site-packages\spatialdm\main.py:41, in weight_matrix.<locals>._Euclidean_to_RBF(X, l, singlecell)
#      39 # At single-cell resolution, no within-spot communications
#      40 if singlecell:
# ---> 41     np.fill_diagonal(rbf_d, 0)
#      42 else:
#      43     rbf_d.setdiag(np.exp(-X.diagonal()**2 / (2 * l ** 2)))
#
# File <__array_function__ internals>:200, in fill_diagonal(*args, **kwargs)
#
# File ~\anaconda3\envs\bio\lib\site-packages\numpy\lib\index_tricks.py:917, in fill_diagonal(a, val, wrap)
#     914     step = 1 + (cumprod(a.shape[:-1])).sum()
#     916 # Write the value out into the diagonal.
# --> 917 a.flat[:end:step] = val
#
# File ~\anaconda3\envs\bio\lib\site-packages\scipy\sparse\_base.py:771, in spmatrix.__getattr__(self, attr)
#     769     return self.getnnz()
#     770 else:
# --> 771     raise AttributeError(attr + " not found")
#
# AttributeError: flat not found

# %%
sdm.weight_matrix(adata, l=150, cutoff=0.2, single_cell=False, eff_dist = 25) # weight_matrix by rbf kernel

# %% [markdown]
# <div class="alert alert-info">
#
# **Note**
#
# If the scale of the spatial coordinates is larger (e.g. several thousand in the intestinal example) or smaller, or when the spot-spot distance varies (which is common for different platforms), the `l` can be very different. It's a crucial step to determine a suitable `l` to match the biological context. We recommend the following plotting to check the resulting weight matrix from the previous step. If needed, users can run ```weight_matrix``` iteratively to decide the most optimal `l` and `cutoff`.
# You can also use the parameter `eff_dist` to help you determine `l`. It stands for the maximum distance between two points that can influence each other.  `eff_dist` also relies heavily on the scale of the spatial coordinates. Try to provide at least one good estimate of `l` and `eff_dist` to enable the clustering algorithm function better.
# </div>

# %%
adata.obsm['spatial'] = adata.obsm['spatial'].values
sdm.weight_matrix(adata, l=70, cutoff=0.2, single_cell=False) # weight_matrix by rbf kernel
# sdm.extract_lr(adata, 'human', min_cell=3)      # find overlapping LRs from CellChatDB
# sdm.spatialdm_global(adata, 1000, specified_ind=None, method='z-score', nproc=1)     # global Moran selection
# sdm.sig_pairs(adata, method='z-score', fdr=True, threshold=0.1)     # select significant pairs
# sdm.spatialdm_local(adata, n_perm=1000, method='z-score', specified_ind=None, nproc=1)     # local spot selection
# sdm.sig_spots(adata, method='z-score', fdr=False, threshold=0.1)   
# print(' done!')

# %%
# visualize range of interaction
import matplotlib.pyplot as plt
plt.figure(figsize=(3,3))

# plt.scatter(adata.obsm['spatial'][:,0], adata.obsm['spatial'][:,1], 
#             c=adata.obsp['weight'][50])

plt.scatter(adata.obsm['spatial'][:,0], adata.obsm['spatial'][:,1], 
            c=adata.obsp['weight'].A[50])

# %% [markdown]
# Next step is to extract valid LR pairs from the database (by default, we use CellChatDB). Filtering out sparsely expressed ligand or receptor (e.g. 3) can help us get more interpretable results later.

# %%
sdm.extract_lr(adata, 'human', min_cell=3)      # find overlapping LRs from CellChatDB
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sdm.extract_lr(adata, 'human', min_cell=3)
#
# File ~\anaconda3\envs\bio\lib\site-packages\spatialdm\main.py:165, in extract_lr(adata, species, mean, min_cell, datahost)
#     162     meanL = adata[:, ligand[i]].X.mean(axis=1)
#     163     meanR = adata[:, receptor[i]].X.mean(axis=1)
#     164 if (sum(meanL > 0) >= min_cell) * \
# --> 165         (sum(meanR > 0) >= min_cell):
#     166     t.append(True)
#     167 else:
#
# File ~\anaconda3\envs\bio\lib\site-packages\numpy\matrixlib\defmatrix.py:168, in matrix.__array_finalize__(self, obj)
#     167 def __array_finalize__(self, obj):
# --> 168     self._getitem = False
#     169     if (isinstance(obj, matrix) and obj._getitem): return
#     170     ndim = self.ndim
#
# KeyboardInterrupt:

# %% [markdown]
# ## Global and local selection (permutation approach)

# %% [markdown]
# It is a crucial step to identify dataset-specific interacting LR pairs (global selection) for ensuring quality analysis and reliable interpretation of the putative CCC. With high computation efficiency, SpatialDM can complete global selection in seconds.

# %%
import time
start = time.time()
sdm.spatialdm_global(adata, 1000, specified_ind=None, method='z-score', nproc=1)     # global Moran selection
sdm.sig_pairs(adata, method='z-score', fdr=True, threshold=0.1)     # select significant pairs
print("%.3f seconds" %(time.time()-start))
# Out:
# 6.415 seconds

# %% [markdown]
# We used fdr corrected global p-values and a threshold FDR < 0.1 (default) to determine which pairs to be included in the following local identification steps. There are 103 pairs being selected in this data.

# %%
print(adata.uns['global_res'].selected.sum())
adata.uns['global_res'].sort_values(by='fdr').head()
# Out:
# 439
#               Ligand0 Ligand1 Ligand2 Receptor0 Receptor1 Receptor2 Receptor3  \
# F11R_F11R        F11R    None    None      F11R      None      None      None
# PECAM1_PECAM1  PECAM1    None    None    PECAM1      None      None      None
# OCLN_OCLN        OCLN    None    None      OCLN      None      None      None
# CD99_CD99        CD99    None    None      CD99      None      None      None
# CDH1_CDH1        CDH1    None    None      CDH1      None      None      None
#
#                z_pval          z  fdr  selected
# F11R_F11R         0.0  44.388374  0.0      True
# PECAM1_PECAM1     0.0  52.959830  0.0      True
# OCLN_OCLN         0.0  43.196174  0.0      True
# CD99_CD99         0.0  44.062576  0.0      True
# CDH1_CDH1         0.0  59.764236  0.0      True

# %% [markdown]
# Local selection is then carried out for the selected 103 pairs to identify where the LRI take place, in a single-spot resolution.

# %%
start = time.time()
sdm.spatialdm_local(adata, n_perm=1000, method='z-score', specified_ind=None, nproc=1)     # local spot selection
sdm.sig_spots(adata, method='z-score', fdr=False, threshold=0.1)     # significant local spots
print("%.3f seconds" %(time.time()-start))
# Out:
# 1.699 seconds

# %% [markdown]
# By default, local selection is performed for all selected pairs in the previous step.

# %% [markdown]
# <div class="alert alert-info">
#
# **Note**
# Apply an array of integer indices of selected pairs to `select_num` to run local selection in selected pairs
# </div>

# %% [markdown]
# The global and local results are easily accessible through ```global_res``` and ```local_perm_p``` or ```local_z_p```

# %% [markdown]
# ## Visualize pair(s)

# %% [markdown]
# SpatialDM provides plotting utilities for general summary of global results:

# %%
pl.global_plot(adata, pairs=['SPP1_CD44', 'CSF1_CSF1R', 'VEGFA_VEGFR2', 'ANGPTL4_SDC2'], 
               figsize=(6,5), cmap='RdGy_r', vmin=-1.5, vmax=2)

# %% [markdown]
# Known melanoma-related pairs were all observed in the selected pairs. It would then be meaningful to investigate the spatial context of their interactions.

# %%
# visualize known melanoma pairs
pl.plot_pairs(adata, ['CSF1_CSF1R', 'VEGFA_VEGFR2', 'CXCL12_CXCR4'], marker='s')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\bio\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\envs\bio\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\bio\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'VEGFA_VEGFR2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 # visualize known melanoma pairs
# ----> 2 pl.plot_pairs(adata, ['CSF1_CSF1R', 'VEGFA_VEGFR2', 'CXCL12_CXCR4'], marker='s')
#
# File ~\anaconda3\envs\bio\lib\site-packages\spatialdm\plottings.py:381, in plot_pairs(sample, pairs_to_plot, pdf, figsize, cmap, cmap_l, cmap_r, **kwargs)
#     379 else:
#     380     for pair in pairs_to_plot:
# --> 381         plot_selected_pair(sample, pair, spots, selected_ind, figsize, cmap=cmap,
#     382                            cmap_l=cmap_l, cmap_r=cmap_r, **kwargs)
#     383         plt.show()
#     384         plt.close()
#
# File ~\anaconda3\envs\bio\lib\site-packages\spatialdm\plottings.py:335, in plot_selected_pair(sample, pair, spots, selected_ind, figsize, cmap, cmap_l, cmap_r, **kwargs)
#     333 plt.figure(figsize=figsize)
#     334 plt.subplot(1, 5, 1)
# --> 335 plt.scatter(spatial_loc[:,0], spatial_loc[:,1], c=spots.loc[pair], cmap=cmap,
#     336             vmax=1, **kwargs)
#     337 plt_util('Moran: ' + str(sample.uns['local_stat']['n_spots'].loc[pair]) + ' spots')
#     339 for l in range(l1):
#
# File ~\anaconda3\envs\bio\lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\envs\bio\lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\envs\bio\lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\envs\bio\lib\site-packages\pandas\core\generic.py:4095, in NDFrame.xs(self, key, axis, level, drop_level)
#    4093             new_index = index[loc]
#    4094 else:
# -> 4095     loc = index.get_loc(key)
#    4097     if isinstance(loc, np.ndarray):
#    4098         if loc.dtype == np.bool_:
#
# File ~\anaconda3\envs\bio\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'VEGFA_VEGFR2'

# %% [markdown]
# ## Spatial Clustering of Local Spots

# %% [markdown]
# [SparseAEH](https://github.com/jackywangtj66/SparseAEH) allows clustering of spatially auto-correlated genes. Here, we repurposed SpatialDE to identify spatially auto-correlated interactions by using binary local selection status as input.

# %%
from SparseAEH import MixedGaussian
from SparseAEH.plot import plot_clusters

# %% [markdown]
# Filter out sparse interactions with fewer than 3 identified interacting spots.
# Cluster into 6 patterns.

# %%
bin_spots = adata.uns['selected_spots'].astype(int)[adata.uns['local_stat']['n_spots']>2]
print(bin_spots.shape[0], " pairs used for spatial clustering")
Y = bin_spots.to_numpy()
# Out:
# 438  pairs used for spatial clustering

# %%
gaussian = MixedGaussian(adata.obsm['spatial'],group_size=16,d=30,l=1e-5)
cluster = gaussian.run_cluster(Y.T,3,iter=50,init_mean='k_means')
# Out:
# C:\Users\ericn\anaconda3\envs\bio\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Iteration 0
# updating variance
# Iteration 1

# %%
plot_clusters(gaussian,figsize=(8,6),s=35)

# %% [markdown]
# SpatialDM provides `compute_pathway` function to group a list of interactions based on the pathways they belong. The input can be a dictionary of several lists.

# %%
dic=dict()
for i in range(gaussian.K):
    dic['Pattern_{}'.format(i)]=bin_spots.index[gaussian.labels==i]

# %% [markdown]
# Save the anndata file to retrieve later

# %%
adata_out = adata.copy()
adata_out.uns['local_stat']['local_permI'] = 'None'
adata_out.uns['local_stat']['local_permI_R'] = 'None'

sdm.write_spatialdm_h5ad(adata_out, filename='mel_sdm_out.h5ad')
# sdm.read_spatialdm_h5ad(filename='mel_sdm_out.h5ad')

# %% [markdown]
# Conduct pathway enrichment analysis

# %%
pathway_res = sdm.compute_pathway(adata,dic=dic)
pathway_res
# Out:
#                                                 total_genes  \
# pathway
# ACTIVIN   INHBA_ACVR1B_ACVR2A        INHBA_ACVR1B_ACVR2A...
# ADGRE5    ADGRE5_CD55    ADGRE5_CD55
# Name: interaction_n...
# AGRN      AGRN_DAG1    AGRN_DAG1
# Name: interaction_name,...
# AGT       AGT_AGTR1B    AGT_AGTR1B
# Name: interaction_nam...
# ALCAM     ALCAM_CD6    ALCAM_CD6
# Name: interaction_name,...
# ...                                                     ...
# VISFATIN  NAMPT_INSR                  NAMPT_INSR
# NAMPT_I...
# VISTA     VSIR_IGSF11    VSIR_IGSF11
# Name: interaction_n...
# VWF       VWF_ITGAV_ITGB3                    VWF_ITGAV_I...
# WNT       WNT10B_FZD9_LRP6      WNT10B_FZD9_LRP6
# WNT10B_...
# ncWNT     WNT5B_FZD9    WNT5B_FZD9
# WNT5B_FZD8    WNT5B_F...
#
#                                                 query_genes overlapped_genes  \
# pathway
# ACTIVIN   {COL9A1_ITGA9_ITGB1, WNT4_FZD9_LRP5, WNT11_FZD...               {}
# ADGRE5    {COL9A1_ITGA9_ITGB1, WNT4_FZD9_LRP5, WNT11_FZD...               {}
# AGRN      {COL9A1_ITGA9_ITGB1, WNT4_FZD9_LRP5, WNT11_FZD...               {}
# AGT       {COL9A1_ITGA9_ITGB1, WNT4_FZD9_LRP5, WNT11_FZD...               {}
# ALCAM     {COL9A1_ITGA9_ITGB1, WNT4_FZD9_LRP5, WNT11_FZD...      {ALCAM_CD6}
# ...                                                     ...              ...
# VISFATIN  {COL6A2_ITGA2_ITGB1, COL1A2_ITGA9_ITGB1, COL6A...               {}
# VISTA     {COL6A2_ITGA2_ITGB1, COL1A2_ITGA9_ITGB1, COL6A...               {}
# VWF       {COL6A2_ITGA2_ITGB1, COL1A2_ITGA9_ITGB1, COL6A...               {}
# WNT       {COL6A2_ITGA2_ITGB1, COL1A2_ITGA9_ITGB1, COL6A...               {}
# ncWNT     {COL6A2_ITGA2_ITGB1, COL1A2_ITGA9_ITGB1, COL6A...               {}
#
#                                     background_mapped_genes  \
# pathway
# ACTIVIN                                                  {}
# ADGRE5                                        {ADGRE5_CD55}
# AGRN                                                     {}
# AGT                                                      {}
# ALCAM                                                    {}
# ...                                                     ...
# VISFATIN                                       {NAMPT_INSR}
# VISTA                                                    {}
# VWF                                                      {}
# WNT       {WNT4_FZD6_LRP5, WNT4_FZD9_LRP5, WNT2B_FZD4_LR...
# ncWNT                                          {WNT11_FZD5}
#
#                                   background_unmapped_genes  selected  \
# pathway
# ACTIVIN   {COL6A2_ITGA2_ITGB1, LAMA1_ITGA6_ITGB1, ANGPTL...         0
# ADGRE5    {COL6A2_ITGA2_ITGB1, LAMA1_ITGA6_ITGB1, ANGPTL...         0
# AGRN      {COL6A2_ITGA2_ITGB1, LAMA1_ITGA6_ITGB1, ANGPTL...         0
# AGT       {COL6A2_ITGA2_ITGB1, LAMA1_ITGA6_ITGB1, ANGPTL...         0
# ALCAM     {COL6A2_ITGA2_ITGB1, LAMA1_ITGA6_ITGB1, ANGPTL...         1
# ...                                                     ...       ...
# VISFATIN  {COL9A1_ITGA9_ITGB1, ANGPTL4_SDC1, WNT11_FZD5,...         0
# VISTA     {COL9A1_ITGA9_ITGB1, ANGPTL4_SDC1, WNT11_FZD5,...         0
# VWF       {COL9A1_ITGA9_ITGB1, ANGPTL4_SDC1, WNT11_FZD5,...         0
# WNT       {COL9A1_ITGA9_ITGB1, ANGPTL4_SDC1, WNT11_FZD5,...         0
# ncWNT     {COL9A1_ITGA9_ITGB1, ANGPTL4_SDC1, COL4A4_ITGA...         0
#
#           fisher_p    pattern
# pathway
# ACTIVIN   1.000000  Pattern_0
# ADGRE5    1.000000  Pattern_0
# AGRN      1.000000  Pattern_0
# AGT       1.000000  Pattern_0
# ALCAM     0.221761  Pattern_0
# ...            ...        ...
# VISFATIN  1.000000  Pattern_2
# VISTA     1.000000  Pattern_2
# VWF       1.000000  Pattern_2
# WNT       1.000000  Pattern_2
# ncWNT     1.000000  Pattern_2
#
# [501 rows x 8 columns]

# %% [markdown]
# In the dot plot of the lymphoid-associated pattern, we identified CD23 and other immune-related pathways.

# %%
pl.dot_path(pathway_res, figsize=(6,12))

# %% [markdown]
# SpatialDM provides `chord_celltype` and other chord diagrams to visualize the aggregated cell types (or interactions)

# %%
adata.obsm['celltypes'] = adata.obs[adata.obs.columns]
pl.chord_celltype(adata, pairs=['FCER2A_CR2'], ncol=1, min_quantile=0.01)
# save='mel_FCER2A_CR2_ct.svg'
# Out:
#   <div id="da8c40ee-f60e-45f1-81f4-2357f3fbd5a5" data-root-id="p1165" style="display: contents;"></div>
# GridPlot(id='p1165', ...)

# %% [markdown]
# ### alternative DE input with Moran R values

# %%
# local_sum = adata.uns['selected_spots'].copy()
# local_sum=local_sum.transpose()
# local_sum[local_sum.columns] =(adata.uns['local_stat']['local_I'] + adata.uns['local_stat']['local_I'])

# results = SpatialDE.run(adata.obsm['spatial'], local_sum)

# histologyesults, patterns = SpatialDE.aeh.spatial_patterns(adata.obsm['spatial'], local_sum,
#                                                              results, C=3, l=5,
#                                                              verbosity=1)
# plt.figure(figsize=(9,8))
# for i in range(3):
#     plt.subplot(2, 2, i + 1)
#     plt.scatter(adata.obsm['spatial'][:,0], adata.obsm['spatial'][:,1], marker = 's',c=patterns[i], s=35);
#     plt.axis('equal')
#     pl.plt_util('Pattern {} - {} genes'.format(i, histologyesults.query('pattern == @i').shape[0] ))

# %% [markdown]
# ## Cell type prediction with local Moran

# %% [markdown]
# Interestingly, the interaction profile of each cell actually may have good concordence to the cell type identity. To varify this, we used the ligand-receptor interaction profile to predict the cell type label that was annotated from the original study.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <div class="alert alert-info">
#
# **Note**
# The prediction results may differ by different annotation accuracy and potentially other factor. Here we generated the cell type decomposition results using RCTD.
# </div>

# %%
X = adata.uns['local_z_p'].values
y=adata.obs.values

reg = LinearRegression().fit(X.T, y)
y_pred = reg.predict(X.T)
pl.corr_plot(np.hstack(y),np.hstack(y_pred), method='pearson')
plt.xlabel('observed cell type weights')
plt.ylabel('predicted cell type weights')
plt.title('linear regression prediction')
# plt.savefig('linear_regression_celltype.pdf')
# Out:
# Text(0.5, 1.0, 'linear regression prediction')

# %% [markdown]
# ## Consistency between permutation and z-score approaches

# %% [markdown]
# In our work, we implemented two methods for hypothesis testing, `method='permutation'` or `method='z-score'` or `method='both'`.
#
# For the z-score method, we derived the first and second moments of the null distribution to analytically obtain a z-score and its according p-values, which are highly consistent with the permutation method.
# Here, we run both and compare the consistency.

# %%
sdm.spatialdm_global(adata, 1000, specified_ind=None, method='both', nproc=1)     # global Moran selection
sdm.sig_pairs(adata, method='z-score', fdr=True, threshold=0.1)     # select significant pairs
# Out:
# 100%|██████████| 1000/1000 [05:19<00:00,  3.13it/s]

# %%
sdm.spatialdm_local(adata, n_perm=1000, method='both', specified_ind=None, nproc=1)     # local spot selection
# Out:
# C:\Users\ericn\anaconda3\envs\bio\lib\site-packages\spatialdm\utils.py:236: RuntimeWarning: invalid value encountered in divide
#   X = X/X.max()
# 100%|██████████| 1000/1000 [01:50<00:00,  9.02it/s]
# 100%|██████████| 1000/1000 [03:10<00:00,  5.24it/s]

# %%
# global consistency
x = -np.log10(adata.uns['global_res']['z_pval'].values)
y = -np.log10(adata.uns['global_res']['perm_pval'].values)
 
x = np.where(x>3, 3, x)
y = np.where(np.isinf(y), 3, y)
pl.corr_plot(x, y, method='spearman')
plt.xlabel('-log10(p) (z-test)')
plt.ylabel('-log10(p) (permutation)')
plt.title('Global p-value correlation (Permutation vs. z-score)')
plt.savefig('mel_perm_z_corr.pdf')
# Out:
# C:\Users\ericn\AppData\Local\Temp\ipykernel_32396\1909596679.py:2: RuntimeWarning: divide by zero encountered in log10
#   x = -np.log10(adata.uns['global_res']['z_pval'].values)
# C:\Users\ericn\AppData\Local\Temp\ipykernel_32396\1909596679.py:3: RuntimeWarning: divide by zero encountered in log10
#   y = -np.log10(adata.uns['global_res']['perm_pval'].values)

# %%
# local consistency
plt.figure(figsize=(4,4))
x=(adata.uns['local_z_p']<0.1).sum(1).values
y=(adata.uns['local_perm_p']<0.1).sum(1).values
pl.corr_plot(x, y, method='pearson')
plt.title('Correlation of number of selected \nlocal spots (Permutation vs. z-score)')
plt.savefig('mel_local_cor.pdf')

# %% [markdown]
# ## Spatial Clustering using SpatialDE

# %% [markdown]
# We have now employed SparseAEH instead of the original method SpatialDE for faster calculation of high-dimensional data.

# %%
# import NaiveDE
# import SpatialDE

# # SpatialDE code
# bin_spots = adata.uns['selected_spots'].astype(int)[adata.uns['local_stat']['n_spots']>2]
# print(bin_spots.shape[0], " pairs used for spatial clustering")

# from threadpoolctl import threadpool_limits

# with threadpool_limits(limits=1, user_api='blas'):
#     results = SpatialDE.run(adata.obsm['spatial'], bin_spots.transpose())
    
#     histology_results, patterns = SpatialDE.aeh.spatial_patterns(
#         adata.obsm['spatial'], bin_spots.transpose(), results, C=3, l=3, verbosity=1)
    
# plt.figure(figsize=(9,8))
# for i in range(3):
#     plt.subplot(2, 2, i + 2)
#     plt.scatter(adata.obsm['spatial'][:,0], adata.obsm['spatial'][:,1], marker = 's',c=patterns[i], s=35);
#     plt.axis('equal')
#     pl.plt_util('Pattern {} - {} genes'.format(i, histology_results.query('pattern == @i').shape[0] ))
# plt.savefig('mel_DE_clusters.pdf')
